# %% [markdown]
# This certificate should be updated with the value of the embedded template items in square brackets:
# -[student]
# -[course]
# -[semester]
# -[instructor]
# -[section]
# The values of the template items can be found in student_list.txt (located in the same file as certificate.txt) which contains the list of students with each line containing the information to add in the certificate. The pieces of information on one single line are separated by commas.The first line in the file indicates the names and order of the placeholder
#
# ![image.png](attachment:image.png)
#
#
# 1)Write a program which will generate several individual certificates. The certificates should be generated in the same folder as the program and should be named with the following format: certificate_for_[student].txtAny space in [student] should be replaced with an underscore _ for the filenames.
# Hint: The replace method on strings can be useful
