# %% [markdown]
# Design a program that asks the user to enter a store’s sales for each day of the week.  The amounts should be stored in a list.  Use a loop to calculate the total sales for the week and display the result.

# %%
sales=[]
sx=0
sum=0
for i in range (7):
    sx=int(input(f"Enter the sales of day {i+1}: "))
    sales.append(sx)
for items in sales:
    sum=sum+items
print("Total sales for the week is:", sum)
# Out:
# Total sales for the week is: 1026

# %% [markdown]
# Design a program that generates a seven-digit lottery number.  The program should generate seven random numbers, each in the range of 0 through 9, and assign each number to a list element.  Then write another loop that displays the contents of the list.

# %%
import random
lottery=[]
x=0
for i in range(7):
    x=random.randint(0,9)
    lottery.append(x)
for item in lottery:
    print(item)
# Out:
# 8
# 0
# 0
# 2
# 0
# 2
# 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
numbers = []
for i in range(20):
    x = random.randint(1, 100)
    numbers.append(x)
g = numbers[0]
s = numbers[0]
add = 0
for item in numbers:
    if item > g:
        g = items
    if item < s:
        s = item
for item in numbers:
    add += item
avg = add / len(numbers)
print("The highest number is", g)
print("The lowest number is", s)
print("The sum of the numbers is", add)
print("The average of the numbers is", avg)
# Out:
# The highest number is 99
# The lowest number is 1
# The sum of the numbers is 1038
# The average of the numbers is 51.9

# %% [markdown]
# In a program, write a function that accepts two arguments:  a list, and a number n.  Assume that the list contains numbers.  The function should display all of the numbers in the list that are greater than the number n

# %%
def my_function(L,n):
    for item in L:
        if item>n:
            print(item, end=" ")
#checking the code:
my_function([12,14,5,23],6)
# Out:
# 12 14 23

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def is_lo_shu(A):
    sumd=0
    sumh=0
    sumv=0
    d=False
    h=False
    v=False
    for i in range(len(A)):
        for j in range(len(A[i])):
            if i==j:
                sumd=sumd+A[i][j]
            if i!=j:
                sumh=sumh+A[i][j]
                sumv=sumv+A[j][i]
    if int(sumv/2)==15 and int(sumh/2) and sumd==15:
        print("It is a LoShu Grid")
    else:
        print("It is not a LoShu Grid")
#checking
is_lo_shu([[4,9,2],[3,5,7],[8,1,6]])
# Out:
# It is a LoShu Grid
